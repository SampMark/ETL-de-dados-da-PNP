# %% [markdown]
# <a href="https://colab.research.google.com/github/SampMark/ETL-de-dados-da-PNP/blob/main/ETL_Portal_Dados_Abertos_IFRN___Tabela__Servidores.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ETL para dados abertos do IFRN - tabela `servidores`
#
# O objetivo deste código é criar um **pipeline de dados automatizado no modelo ETL (Extract, Transform, Load)** para transformar dados públicos brutos em um ambiente de alta performance para análise de dados:
#
# 1.  **Extrair (Extract)**: coletar de forma automática os dados públicos sobre os servidores do IFRN diretamente de seu portal de dados abertos.
# 2.  **Transformar (Transform)**: limpar, padronizar, enriquecer e modelar esses dados brutos, convertendo-os de um formato inconsistente para um conjunto de dados limpo, coeso e pronto para análise.
# 3.  **Carregar (Load)**: enviar o conjunto de dados já tratado para o **Google BigQuery**, um data warehouse na nuvem, que pode ser facilmente consultado, analisado e utilizado para criar painéis de _Business Intelligence_ (BI), relatórios e outras análises de dados.
#
# O script executa uma sequência lógica e bem definida de etapas para atingir seu objetivo. O fluxo de trabalho é o seguinte:
#
# ## Fluxo de Trabalho
#
# ### **1. Autenticação e configuração inicial**:
# O script começa autenticando o usuário no ambiente do Google Cloud. Este é um pré-requisito essencial para permitir que o código tenha permissão para gravar dados no BigQuery no final do processo.
#
# ### **2. Extração de metadados (_web scraping_)**:
# * **Ação**: o código acessa a página web do dataset de servidores (`https://dados.ifrn.edu.br/dataset/servidores`) e utiliza a técnica de **Web Scraping** para extrair a data de "Última Atualização".
# * **Propósito**: esta etapa é crucial para rastrear a "validade" ou "atualidade" dos dados. A data extraída é posteriormente adicionada a cada registro, permitindo saber a qual "fotografia" do tempo aquela informação pertence.
# * **Tratamento**: a data extraída é formatada para o padrão `DD/MM/AAAA`.
#
# #### **3. Extração dos Dados Principais**
# * **Ação**: O script carrega o arquivo CSV contendo os dados brutos de todos os servidores diretamente da URL fornecida pelo portal de dados abertos.
# * **Propósito**: Esta é a etapa principal de extração, onde o conjunto de dados a ser trabalhado é carregado em um **DataFrame** do pandas.
#
# #### **4. Transformação e Limpeza dos Dados**
# * Esta é a etapa mais extensa, onde a "mágica" da limpeza acontece. O código aplica uma série de tratamentos para padronizar e corrigir as inconsistências em várias colunas:
#     * **`categoria`**: Padroniza os vínculos (ex: `docente` vira `Docente`).
#     * **`campus`**: Converte siglas em nomes completos (ex: `CNAT` vira `Campus Natal - Central`), tornando os dados mais legíveis para o usuário final.
#     * **`setor_suap`**: Remove a redundância do campus (ex: `DIAC/ZL` vira `DIAC`), o que permite agrupar os setores corretamente em análises.
#     * **`funcao`**: Limpa a descrição da função, mantendo apenas o código principal (ex: `CD0004 - DIAD/ZN` vira `CD0004`).
#     * **`jornada_trabalho`**: Simplifica as descrições (ex: `40 HORAS SEMANAIS` vira `40h Semanais`).
#     * **`disciplina_ingresso`**: Um tratamento complexo que atribui "Não se Aplica" para servidores não docentes e limpa os valores para os docentes.
#
# #### **5. Preparação do DataFrame Final para BI**
# * **Ação**: O script seleciona apenas as colunas que foram tratadas e que são relevantes para a análise.
# * **Propósito**: Descarta colunas desnecessárias (como URLs de fotos) e renomeia as colunas restantes para nomes mais descritivos e padronizados, ideais para um ambiente de BI (ex: `categoria_tratada` vira `Vinculo_de_Carreira`). Por fim, adiciona a data de atualização extraída na etapa 2 como uma nova coluna.
#
# #### **6. Carga no BigQuery (Load)**
# * **Ação**: O script se conecta ao projeto Google Cloud especificado e envia o DataFrame final (`df_servidores_bi`) para uma tabela no BigQuery.
# * **Propósito**: Esta é a etapa final do pipeline. Ao usar a opção `if_exists='replace'`, o código garante que a tabela no BigQuery seja sempre substituída pela versão mais recente e tratada dos dados, mantendo o data warehouse sempre atualizado. Ele utiliza um esquema de tabela (`table_schema`) pré-definido para garantir a consistência dos tipos de dados.

# %%
# -*- coding: utf-8 -*-
"""
ETL Completo dos Dados de Servidores do IFRN com Carga no BigQuery.
"""

import re
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
from datetime import datetime
from google.colab import auth
from google.auth import default
import pandas_gbq

# --- Autenticação no Google Cloud (Necessário no Colab) ---
try:
    auth.authenticate_user()
    creds, project_id_default = default()
    pandas_gbq.context.credentials = creds
    pandas_gbq.context.project = project_id_default
    print("✔ Autenticação com o Google Cloud realizada com sucesso!")
except Exception as e:
    print(f"⚠️ Aviso: Falha na autenticação. A exportação para o BigQuery não funcionará. Erro: {e}")
print("-" * 50)
# Out:
# ✔ Autenticação com o Google Cloud realizada com sucesso!
# --------------------------------------------------

# %%
# @title --- 0. Extração da Data de Atualização (Web Scraping) ---
url_pagina = 'https://dados.ifrn.edu.br/dataset/servidores'
print(f"Extraindo a data de última atualização dos dados em {url_pagina}...")
last_updated_date = 'Data não extraída' # Valor padrão

try:
    response = requests.get(url_pagina)
    response.raise_for_status()
    soup = BeautifulSoup(response.content, 'html.parser')
    update_header = soup.find('th', string=re.compile(r'Última Atualização'))
    if update_header:
        update_date_cell = update_header.find_next_sibling('td')
        if update_date_cell:
            last_updated_date = update_date_cell.get_text(strip=True)
            print(f"Data de atualização da base de dados no site: {last_updated_date}")
except requests.exceptions.RequestException as e:
    print(f"Não foi possível extrair a data de atualização. Erro: {e}")

try:
    # 1) Localiza e separa as partes da data usando expressão regular.
    match = re.search(r'(\w+) (\d+), (\d+), (\d+:\d+) \((\w+)\)', last_updated_date)

    if match:
        # 2) Extrai os grupos da regex.
        month_name, day, year, time, timezone = match.groups()

        # 3) Tabela de conversão de nomes de meses (em PT-BR) para números (1–12).
        month_map = {
            'Janeiro': 1, 'Fevereiro': 2, 'Março': 3, 'Abril': 4,
            'Maio': 5, 'Junho': 6, 'Julho': 7, 'Agosto': 8,
            'Setembro': 9, 'Outubro': 10, 'Novembro': 11, 'Dezembro': 12
        }
        month_number = month_map.get(month_name)

        if month_number:
            # 4) Cria um objeto datetime apenas com ano, mês e dia.
            #    (A hora/minuto e o fuso foram ignorados de propósito.)
            date_obj = datetime(int(year), month_number, int(day))

            # 5) Formata a data no padrão DD/MM/AAAA.
            data = date_obj.strftime('%d/%m/%Y')
            print(f"Data formatada (DD/MM/AAAA): {data}")
        else:
            # Caso o nome do mês não esteja no dicionário acima.
            print(f"Não foi possível interpretar o mês: {month_name}")
            data = "Data Não Formatada"
    else:
        # Caso a string não obedeça ao formato esperado pela regex.
        print(f"Formato de data inesperado: {last_updated_date}")
        data = "Data Não Formatada"

except Exception as e:
    # Tratamento genérico de erros (por exemplo, valores inválidos).
    print(f"Ocorreu um erro durante a formatação da data: {e}")
    data = "Data Não Formatada"
print("-" * 50)
# Out:
# Extraindo a data de última atualização dos dados em https://dados.ifrn.edu.br/dataset/servidores...
# Data de atualização da base de dados no site: Março 13, 2025, 10:49 (BRT)
# Data formatada (DD/MM/AAAA): 13/03/2025
# --------------------------------------------------

# %%
# @title --- 1. Carregamento dos Dados ---

# O mesmo link utilizado no seu notebook Colab.
url = 'https://dados.ifrn.edu.br/dataset/0c5c1c1a-7af8-4f24-ba37-a9eda0baddbb/resource/9adf1491-9e7c-4950-ab02-d3e12af37ec2/download/dados_extraidos_recursos_servidores.csv'
df = pd.read_csv(url, sep=';')

print("Dados originais carregados com sucesso.")
print(f"O DataFrame possui {df.shape[0]} linhas e {df.shape[1]} colunas.")
print("-" * 50)

display(df.head())
# Out:
# Dados originais carregados com sucesso.
# O DataFrame possui 2972 linhas e 13 colunas.
# --------------------------------------------------
#                 categoria                                    cargo  \
# 0                 docente    PROFESSOR ENS BASICO TECN TECNOLOGICO
# 1                 docente  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO
# 2  tecnico_administrativo                            ADMINISTRADOR
# 3                 docente    PROFESSOR ENS BASICO TECN TECNOLOGICO
# 4                 docente    PROFESSOR ENS BASICO TECN TECNOLOGICO
#
#   setor_siape   disciplina_ingresso setor_suap  \
# 0     DIAC/ZL              Didática    DIAC/ZL
# 1     DIAC/MO                   NaN    DIAC/MO
# 2     DIAD/ZN                     -    DIAD/ZN
# 3     DIAC/MO  Instalações Prediais    DIAC/MO
# 4     DIAC/JC         Arte - Teatro    DIAC/JC
#
#                                     nome  \
# 0       Abigail Noadia Barbalho da Silva
# 1  Abimael Esdras Carvalho de Moura Lira
# 2                Abinoam Soares da Silva
# 3          Abraao Jhonny da Costa Brazao
# 4          Abraao Lincoln Rosendo Frazao
#
#                                        funcao     jornada_trabalho  \
# 0  FAG-IFRN - UAB/IFRN / FAG-IFRN - CESPEP/ZL  DEDICACAO EXCLUSIVA
# 1                                         NaN    40 HORAS SEMANAIS
# 2                            CD0004 - DIAD/ZN    40 HORAS SEMANAIS
# 3                                         NaN  DEDICACAO EXCLUSIVA
# 4                                         NaN  DEDICACAO EXCLUSIVA
#
#                   telefones_institucionais  matricula  curriculo_lattes  \
# 0             (84) 3092-8915 (ramal: 8915)    1895370               NaN
# 1             (84) 3422-2669 (ramal: 2669)    3268131               NaN
# 2             (84) 4006-9502 (ramal: 9502)    1845427               NaN
# 3             (84) 3422-2669 (ramal: 2669)    1266198               NaN
# 4  ramal: 5604 / ramal: 5629 / ramal: 5625    2460058               NaN
#
#   campus                              url_foto_75x100
# 0     ZL   /media/fotos/75x100/98189.F0xg7aLNxBHA.jpg
# 1     MO  /media/fotos/75x100/387388.o9YeUaXaDOSo.jpg
# 2     ZN    /media/fotos/75x100/9698.fk2bWDbZK29Q.jpg
# 3     MO  /media/fotos/75x100/274524.CADei8Dy0ygg.jpg
# 4     JC  /media/fotos/75x100/170241.0uazsCmttZVZ.jpg

# %%
df['matricula'] = df['matricula'].astype('object')
df['curriculo_lattes'] = df['curriculo_lattes'].astype('object')

display(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2972 entries, 0 to 2971
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   categoria                 2972 non-null   object
#  1   cargo                     2866 non-null   object
#  2   setor_siape               2970 non-null   object
#  3   disciplina_ingresso       2788 non-null   object
#  4   setor_suap                2971 non-null   object
#  5   nome                      2972 non-null   object
#  6   funcao                    735 non-null    object
#  7   jornada_trabalho          2972 non-null   object
#  8   telefones_institucionais  2781 non-null   object
#  9   matricula                 2972 non-null   object
#  10  curriculo_lattes          0 non-null      object
#  11  campus                    2972 non-null   object
#  12  url_foto_75x100           2972 non-null   object
# dtypes: object(13)
# memory usage: 302.0+ KB
# None

# %%
# @title --- 2. Visualização de valores únicos das colunas especificadas ---

columns_to_display = ['categoria', 'cargo', 'disciplina_ingresso', 'setor_suap', 'funcao', 'jornada_trabalho', 'campus']

for column in columns_to_display:
    unique_values = df[column].unique()
    # Convert all values to string before sorting to handle NaN
    unique_values_as_strings = [str(value) for value in unique_values]
    sorted_unique_values = sorted(unique_values_as_strings)
    print(f"\nTotal de valores exclusivos para '{column}': {len(unique_values_as_strings)}")
    print(f"Exibindo valores exclusivos para coluna '{column}':")
    for value in sorted_unique_values:
        print(value)
    print("-" * 30)
# Out:
# Total de valores exclusivos para 'categoria': 4
# Exibindo valores exclusivos para coluna 'categoria':
# docente
# estagiario
# indefinida
# tecnico_administrativo
# ------------------------------
#
# Total de valores exclusivos para 'cargo': 88
# Exibindo valores exclusivos para coluna 'cargo':
# ADMINISTRADOR
# ANALISTA DE TEC DA INFORMACAO
# ARQUITETO E URBANISTA
# ARQUIVISTA
# ASSISTENTE DE ALUNO
# ASSISTENTE DE LABORATORIO
# ASSISTENTE EM ADMINISTRACAO
# ASSISTENTE SOCIAL
# AUDITOR
# AUX EM ADMINISTRACAO
# AUXILIAR DE ARTES GRAFICAS
# AUXILIAR DE BIBLIOTECA
# AUXILIAR DE ELETRICISTA
# AUXILIAR DE ENFERMAGEM
# AUXILIAR DE LABORATORIO
# AUXILIAR DE MECANICA
# AUXILIAR EM ASSUNTOS EDUCACIONAIS
# BIBLIOTECARIO-DOCUMENTALISTA
# CARPINTEIRO
# CONTADOR
# DESENHISTA TECNICO ESPECIALIDADE
# DESENHISTA-PROJETISTA
# DIAGRAMADOR
# ECONOMISTA
# ELETRICISTA
# ENFERMEIRO DO TRABALHO
# ENFERMEIRO-AREA
# ENGENHEIRO AGRONOMO
# ENGENHEIRO DE SEG DO TRABALHO
# ENGENHEIRO-AREA
# ESTAGIARIO DE NIVEL SUPERIOR
# ESTAGIARIO JORNADA 30 HORAS
# ESTAGIARIO NIVEL MEDIO - INPE
# ESTATISTICO
# FISICO
# FISIOTERAPEUTA
# IMPRESSOR
# JORNALISTA
# MARCENEIRO
# MECANICO
# MEDICO VETERINARIO
# MEDICO-AREA
# MOTORISTA
# NUTRICIONISTA-HABILITACAO
# ODONTOLOGO - 30H - DEC JUD
# ODONTOLOGO - 40 HORAS
# OPERADOR DE MAQ DE LAVANDERIA
# OPERADOR DE MAQUINA COPIADORA
# OPERADOR DE TELE-IMPRESSORA
# PEDAGOGO-AREA
# PINTOR-AREA
# PORTEIRO
# PROCURADOR FEDERAL
# PRODUTOR CULTURAL
# PROF DO ENSINO BASICO TEC TECNOLOGICO
# PROF ENS BAS TEC TECNOLOGICO - VISITANTE
# PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO
# PROFESSOR ENS BASICO TECN TECNOLOGICO
# PROGRAMADOR VISUAL
# PSICOLOGO-AREA
# PUBLICITARIO
# REDATOR
# REVISOR DE TEXTOS
# SECRETARIO EXECUTIVO
# SERVENTE DE LIMPEZA
# SERVENTE DE OBRAS
# TEC DE TECNOLOGIA DA INFORMACAO
# TEC EM METROLOGIA E QUALIDADE
# TEC EM SEGURANCA DO TRABALHO
# TECNICO DE LABORATORIO AREA
# TECNICO EM AGROPECUARIA
# TECNICO EM ALIMENTOS E LATICINIOS
# TECNICO EM ASSUNTOS EDUCACIONAIS
# TECNICO EM AUDIOVISUAL
# TECNICO EM CONTABILIDADE
# TECNICO EM EDIFICACOES
# TECNICO EM ELETROTECNICA
# TECNICO EM ENFERMAGEM
# TECNICO EM HIGIENE DENTAL
# TECNICO EM MECANICA
# TECNICO EM MINERACAO
# TECNICO EM QUIMICA
# TECNICO EM SECRETARIADO
# TECNOLOGO-FORMACAO
# TELEFONISTA
# TRADUTOR INTERPRETE DE LINGUAGEM SINAIS
# VIGILANTE
# nan
# ------------------------------
#
# Total de valores exclusivos para 'disciplina_ingresso': 173
# Exibindo valores exclusivos para coluna 'disciplina_ingresso':
# -
# Administração
# Administração Contábil e Financeira
# Administração Financeira
# Administração Pública
# Administração de Processos e Operações
# Agroecologia/Engenharia Rural
# Agronomia
# Alimentos
# Apicultura
# Arte
# Arte - Artes Visuais
# Arte - Dança
# Arte - Música
# Arte - Teatro
# Arte e Desenho
# Avaliação de Formação e Análise de Fluidos
# Beneficiamento Têxtil
# Biocombustíveis
# Biologia
# Biologia Marinha
# Biologia, Bioquímica e Microbiologia
# Biotecnologia
# Captação e Desenho de Som para Áudio e Vídeo
# Conservação e Restauração de Bens Culturais Imóveis
# Construção Civil
# Construção Civil e Materiais de Construção
# Construção de Estradas
# Controle  Ambiental
# Controle de Processos
# Controle de Qualidade de Alimentos
# Controle e Qualidade de Alimentos
# Cooperativismo
# Cálculo Diferencial e Integral e Algebra Linear
# Desenho Técnico
# Desenho e CAD
# Desenvolvimento de Jogos Digitais
# Desenvolvimento de Software
# Design, Multimídia, Construção de Personagens e Narrativas para Jogos Digitais
# Didática
# Direito
# Direção e Fotografia e Manipulação de Câmeras
# Edição de Vídeo e Animação 2D e 3D
# Educação Física
# Educação Matemática
# Eletricidade e Eletrônica
# Eletroeletrônica
# Eletromecânica
# Eletrotécnica
# Eletrônica
# Energias Renováveis
# Engenharia Ambiental
# Engenharia Sanitária
# Engenharia de Pesca
# Engenharia de Produção
# Equipamentos Biomédicos
# Espanhol
# Estatística Básica, Estatística Aplicada e afins
# Eventos
# Fabricação Mecânica
# Filosofia
# Fisicoquímica
# Fitossanidade
# Fundamentos da Administração
# Fundamentos da Administração, Gestão de Negócios e Marketing
# Fundamentos do Turismo
# Física
# Geografia
# Geografia e Meio Ambiente
# Geologia
# Gestão
# Gestão Ambiental
# Gestão Desportiva e do Lazer
# Gestão Organizacional
# Gestão Organizacional, Cooperativismo, Terceiro Setor e Empreendedorismo
# Gestão da produção e Logística
# Gestão de Cooperativas e Agronegócios
# Gestão de Negócios
# Gestão e Qualidade na Construção Civil
# Guia de Turismo
# Higiene e Saúde do Trabalho
# História
# Informática
# Informática aplicada ao Design Gráfico
# Infraestrutura
# Instalações Elétricas Residenciais e Industriais
# Instalações Prediais
# Irrigação Pressurizada
# Libras
# Linguagem de programação e Informática
# Logística
# Língua Espanhola
# Língua Francesa
# Língua Inglesa
# Língua Portuguesa
# Língua Portuguesa e Literatura Brasileira
# Língua portuguesa/Espanhola
# Manutenção de Computadores
# Manutenção de Equipamentos de Informática
# Manutenção de Máquinas e Motores Marítimos, Instalações Elétricas e Hidráulicas
# Manutenção e Suporte em Informática
# Marketing
# Marketing e Multimídia
# Matemática
# Materiais de Construção
# Mecatrônica
# Mecânica
# Mecânica e Materiais
# Mecânica, Hidráulica e Pneumática
# Mecânica/Refrigeração e Climatização
# Medidas Elétricas
# Meio Ambiente e Agroecologia
# Metodologia do Trabalho Científico
# Mineração
# Moda e Produção de Vestuário
# Modelagem e Confecção de Vestuário
# Máquinas e Instalações Elétricas e Eletrônicas
# Música - Piano/Teclado/Acordeon
# Novas Tecnologias da Informação e Comunicação Aplicada à Educação
# Organização e Normas
# Orçamento de Obras e Gestão de Recursos Humanos e Relações Humanas na Construção Civil
# Pavimentação e Conservação de Estradas
# Petróleo e Gás
# Políticas de Educação Profissional e Formação Docente
# Políticas e Gestão Escolar
# Processamento de Alimentos
# Processos Industriais, Tratamento de Resíduos e Corrosão
# Processos Químicos
# Processos de Gestão e Controle de Qualidade na Indústria do Vestiário
# Produção Cultural
# Produção Industrial
# Produção Textil
# Produção de Audiovisual
# Produção de Petróleo e Gás e Termodinâmica
# Programação e Métodos Computacionais
# Psicologia
# Química
# Química Analítica
# Química Aplicada
# Química Inorgânica
# Química Orgânica
# Recursos Pesqueiros
# Redes de Computadores
# Refrigeração e Climatização
# Saneamento
# Saúde Ocupacional e Primeiros Socorros
# Segurança do Trabalho
# Sistemas Operacionais e Arquitetura de Computadores
# Sistemas Prediais Hidrosanitários
# Sistemas Termofluidos e Instrumentação Industrial
# Sistemas de Computação
# Sistemas de Esgoto Sanitário
# Sistemas de Informação
# Sociologia
# Solos e Topografia
# Tecelagem (Plana e de Malharia)
# Tecnologia Mecânica
# Tecnologia de Processamento de Produtos Apícolas
# Tecnologia em Energia Renovável
# Teoria Geral do Turismo
# Termodinâmica
# Termofluidos e Termociências
# Topografia e Projeto de Estradas
# Topografia; Irrigação e Drenagem; Máquinas e Implementos Agrícolas
# Transporte e Tráfego
# Turismo
# Web Design
# Zootecnia
# Zootecnia Geral
# Zootecnia e Defesa Santária Animal
# Zootecnia e Gestão do Agronegócio
# nan
# Álgebra Linear e Cálculo Diferencial e Integral
# ------------------------------
#
# Total de valores exclusivos para 'setor_suap': 579
# Exibindo valores exclusivos para coluna 'setor_suap':
# AGDE/PRODES
# ASAC/LAJ
# ASAC/PAAS
# ASADES/PAAS
# ASADM
# ASAES
# ASAES/LAJ
# ASAES/PAAS
# ASAL/PAAS
# ASBIB/AP
# ASBIB/LAJ
# ASCE
# ASCTI/PAAS
# ASERI
# ASESP/LAJ
# ASETEP/PAAS
# ASFIC/LAJ
# ASGPE/LAJ
# ASGPE/PAAS
# ASGPE/ZL
# ASGRIS/DIGPE
# ASLAB/LAJ
# ASPE/PRODES
# ASPED/LAJ
# ASPED/SPP
# ASPLADTI/LAJ
# ASPROC
# ASREMT
# ASSPUB
# ASTE/ZL
# ASTEC
# ASTECFIC/SPP
# AUDGE
# AUDIN/CA
# AUDIN/NC
# AUDIN/SC
# CADIS
# CALMOX/CNAT
# CASEM/CNAT
# CCAGEN/ZN
# CCEDIIT/SGA
# CCEDISB/SGA
# CCEEC
# CCEGA/CNAT
# CCELT/ZN
# CCENGPRO/SGA
# CCESA
# CCINFIT/SGA
# CCLOGCS/SGA
# CCLOGIT/SGA
# CCREDCS/SGA
# CCTCA/CNAT
# CCTG/CNAT
# CCTGA/CNAT
# CCTI/CNAT
# CCTI/NC
# CCTM/CNAT
# CCTMIN/PAAS
# CCTST/CNAT
# CECINAM/AP
# CEE/CNAT
# CEE/MO
# CEEST/CNAT
# CENTEC/CM
# CESPEAGSA/JC
# CESPEP/ZL
# CLIESP/CNAT
# CLIFIS/JC
# CLIGEO/CNAT
# CLIMAT/CNAT
# CLINF/ZN
# CLIPE/CNAT
# CLQ/CN
# CME/ZL
# COADES/AP
# COADES/CA
# COADES/CN
# COADES/CNAT
# COADES/MO
# COADES/PF
# COADES/SC
# COADES/SGA
# COADES/SPP
# COADES/ZN
# COADPE
# COADS
# COAES/AP
# COAES/CA
# COAES/CAL
# COAES/CANG
# COAES/CM
# COAES/CN
# COAES/IP
# COAES/JC
# COAES/MC
# COAES/MO
# COAES/NC
# COAES/PAR
# COAES/PF
# COAES/SC
# COAES/SGA
# COAES/SPP
# COAES/ZN
# COAGRO/AP
# COAPAC/AP
# COAPAC/CA
# COAPAC/CAL
# COAPAC/CANG
# COAPAC/CM
# COAPAC/CN
# COAPAC/IP
# COAPAC/JC
# COAPAC/MC
# COAPAC/NC
# COAPAC/PAR
# COAPAC/PF
# COAPAC/SC
# COAPAC/SGA
# COAPAC/SPP
# COAPAC/ZN
# COAPAT
# COAPIC/PF
# COAPRODEL/CN
# COAS/CNAT
# COASS
# COBIB/CM
# COBIB/CNAT
# COBIB/MO
# COBIO/AP
# COCAB/CNAT
# COCAP/CNAT
# COCINF/CM
# COCINF/LAJ
# COCOM/LAJ
# COCOMP/CNAT
# COCOMP/ZN
# COCSEV/AP
# COCSEV/CAL
# COCSEV/CANG
# COCSEV/CM
# COCSEV/CNAT
# COCSEV/IP
# COCSEV/JC
# COCSEV/MC
# COCSEV/MO
# COCSEV/NC
# COCSEV/PAR
# COCSEV/PF
# COCSEV/SC
# COCSEV/SGA
# COCSEV/ZN
# COCTADM/CNAT
# COCTADM/JC
# COCTECBIO/CM
# CODEPE
# CODEPE/CNAT
# CODESP/CNAT
# COEB/CNAT
# COECNM/MC
# COEDI
# COEDI/MO
# COEDU/MO
# COEECI/CN
# COELE/MO
# COENGCIV
# COESCTAL/CN
# COESP/CM
# COESP/CN
# COESUP/CNAT
# COETEP/CAL
# COEVENTOS/CAL
# COEX/AP
# COEX/CA
# COEX/CAL
# COEX/CANG
# COEX/CM
# COEX/CN
# COEX/IP
# COEX/JC
# COEX/MO
# COEX/NC
# COEX/PAR
# COEX/PF
# COEX/SC
# COEX/SGA
# COEX/SPP
# COEX/ZN
# COEXPEIN/LAJ
# COFIMPAT/LAJ
# COFIMPAT/PAAS
# COFIMPAT/ZL
# COFIN
# COFIN/CNAT
# COFINC/AP
# COFINC/CA
# COFINC/CAL
# COFINC/CANG
# COFINC/CM
# COFINC/CN
# COFINC/IP
# COFINC/JC
# COFINC/MC
# COFINC/MO
# COFINC/NC
# COFINC/PAR
# COFINC/PF
# COFINC/SC
# COFINC/SGA
# COFINC/SPP
# COFINC/ZN
# COGCAP
# COGDL/CAL
# COGEPELE/CAL
# COGPE/AP
# COGPE/CA
# COGPE/CAL
# COGPE/CANG
# COGPE/CM
# COGPE/CN
# COGPE/IP
# COGPE/JC
# COGPE/MC
# COGPE/MO
# COGPE/NC
# COGPE/PAR
# COGPE/PF
# COGPE/SC
# COGPE/SGA
# COGPE/SPP
# COGPE/ZN
# COGTURISMO/CAL
# COIN/JUC
# COINF/MC
# COINF/MO
# COINRE
# COLAB/AP
# COLAB/CA
# COLAB/CAL
# COLAB/CANG
# COLAB/CM
# COLAB/CN
# COLAB/IP
# COLAB/JC
# COLAB/MC
# COLAB/MO
# COLAB/NC
# COLAB/PAR
# COLAB/PF
# COLAB/SC
# COLAB/SGA
# COLAB/SPP
# COLAB/ZL
# COLAB/ZN
# COLABCI/CNAT
# COLABCON/CNAT
# COLABIND/CNAT
# COLABINF/CNAT
# COLABREN/CNAT
# COLAZER/CAL
# COLURB/CNAT
# COMAT/MO
# COMEC/MO
# COMNPEF/CNAT
# COMPAT/AP
# COMPAT/CA
# COMPAT/CAL
# COMPAT/CANG
# COMPAT/CM
# COMPAT/CN
# COMPAT/IP
# COMPAT/JC
# COMPAT/MC
# COMPAT/MO
# COMPAT/NC
# COMPAT/PAR
# COMPAT/PF
# COMPAT/SC
# COMPAT/SGA
# COMPAT/SPP
# COMPAT/ZN
# COMPRO
# COMULT/CA
# COMULT/CAL
# COMULT/CNAT
# COMULT/MO
# COMULT/NC
# COMULT/SGA
# COMULT/ZN
# COMULTIMIDIA
# COMUMI/CNAT
# CONC/CNAT
# COORDELETRO/CNA
# COORDENG/CNAT
# COORDPETRO/CNAT
# COORD_EVEN_INT
# COORD_FIC/CANG
# COORD_GESTUR
# COORD_INFO/CANG
# COORD_MEC/CANG
# COORD_POS_GRAD
# COORD_SISTIN
# COPAT/CNAT
# COPCULTURAL/CAL
# COPED/CNAT
# COPED/ZN
# COPEIN/AP
# COPEIN/CA
# COPEIN/CAL
# COPEIN/CANG
# COPEIN/CM
# COPEIN/CN
# COPEIN/IP
# COPEIN/JC
# COPEIN/MC
# COPEIN/MO
# COPEIN/NC
# COPEIN/PAR
# COPEIN/PF
# COPEIN/SC
# COPEIN/SGA
# COPEIN/SPP
# COPEIN/ZN
# COPET/MO
# COPJODIG/CM
# COPLAV
# COPPgUSRN/CNAT
# COPREC/CNAT
# COPROQ/MC
# COSAAD
# COSAEN
# COSAN/MO
# COSEG/CNAT
# COSGEM/AP
# COSGEM/CA
# COSGEM/CAL
# COSGEM/CANG
# COSGEM/CM
# COSGEM/CN
# COSGEM/IP
# COSGEM/JC
# COSGEM/LAJ
# COSGEM/MC
# COSGEM/MO
# COSGEM/NC
# COSGEM/PAAS
# COSGEM/PAR
# COSGEM/PF
# COSGEM/SC
# COSGEM/SGA
# COSGEM/SPP
# COSGEM/ZN
# COSINF
# COTADS/CNAT
# COTADS/PF
# COTECEDI/DIACON
# COTEDIF/CNAT
# COTEQ/AP
# COTEST/DIACON
# CRA/CNAT
# CSAL/CN
# CSAUDE/CNAT
# CSTEMK/ZN
# CTAGROI/PF
# CTECPROQ/NC
# CTGPUBLICA/CNAT
# CTI/AP
# CTI/CA
# CTI/CAL
# CTI/CANG
# CTI/CM
# CTI/CN
# CTI/IP
# CTI/JC
# CTI/MC
# CTI/MO
# CTI/NC
# CTI/PAR
# CTI/PF
# CTI/SC
# CTI/SGA
# CTI/SPP
# CTI/ZL
# CTI/ZN
# CTINF/CN
# CTINF/ZN
# CTMIN
# CTMS/CM
# CTMS/CN
# CTMS/CNAT
# CTMS/ZN
# CTRECOMP/CNAT
# CTSI/CN
# Coordmec/CNAT
# DE/CNAT
# DEAD/ZL
# DG/AP
# DG/CA
# DG/CAL
# DG/CANG
# DG/CM
# DG/CN
# DG/CNAT
# DG/IP
# DG/JC
# DG/JUC
# DG/LAJ
# DG/MC
# DG/MO
# DG/NC
# DG/PAAS
# DG/PAR
# DG/PF
# DG/SGA
# DG/SPP
# DG/ZL
# DG/ZN
# DIAAC
# DIAC/AP
# DIAC/CA
# DIAC/CAL
# DIAC/CANG
# DIAC/CM
# DIAC/CN
# DIAC/CNAT
# DIAC/IP
# DIAC/JC
# DIAC/JUC
# DIAC/LAJ
# DIAC/MC
# DIAC/MO
# DIAC/NC
# DIAC/PAAS
# DIAC/PAR
# DIAC/PF
# DIAC/SC
# DIAC/SGA
# DIAC/SPP
# DIAC/ZL
# DIAC/ZN
# DIACIN/CNAT
# DIACON/CNAT
# DIAD/AP
# DIAD/CA
# DIAD/CAL
# DIAD/CANG
# DIAD/CM
# DIAD/CN
# DIAD/CNAT
# DIAD/IP
# DIAD/JC
# DIAD/LAJ
# DIAD/MC
# DIAD/MO
# DIAD/NC
# DIAD/PAAS
# DIAD/PAR
# DIAD/PF
# DIAD/SC
# DIAD/SGA
# DIAD/SPP
# DIAD/ZL
# DIAD/ZN
# DIAES/CNAT
# DIAPAC/MO
# DIAPE/CNAT
# DIARE
# DIAREN/CNAT
# DIATINF/CNAT
# DIENG
# DIGAE
# DIGPE
# DIGTI
# DIGUAE/AP
# DIGUAE/IP
# DIGUIE/CN
# DIGUIE/MC
# DIGUIE/PF
# DILIC
# DIPED
# DIPEQ/CNAT
# DIREX/CNAT
# DITEC
# DTI/CNAT
# ETEP/AP
# ETEP/CANG
# ETEP/CM
# ETEP/CN
# ETEP/JC
# ETEP/MC
# ETEP/MO
# ETEP/PF
# ETEP/SC
# ETEP/SGA
# GABIN/AP
# GABIN/CA
# GABIN/CAL
# GABIN/CANG
# GABIN/CM
# GABIN/CN
# GABIN/CNAT
# GABIN/IP
# GABIN/JC
# GABIN/JUC
# GABIN/LAJ
# GABIN/MC
# GABIN/MO
# GABIN/NC
# GABIN/PAAS
# GABIN/PAR
# GABIN/PF
# GABIN/RE
# GABIN/SC
# GABIN/SGA
# GABIN/SPP
# GABIN/ZL
# GABIN/ZN
# GECON/PROAD
# NAPNE/AP
# NAPNE/CA
# NAPNE/CAL
# NAPNE/CANG
# NAPNE/CM
# NAPNE/CN
# NAPNE/CNAT
# NAPNE/IP
# NAPNE/LAJ
# NAPNE/MC
# NAPNE/MO
# NAPNE/NC
# NAPNE/PAAS
# NAPNE/PAR
# NAPNE/PF
# NAPNE/SC
# NAPNE/SGA
# NAPNE/SPP
# NAPNE/ZL
# NAPNE/ZN
# NUARTE/CNAT
# NUCAUDIVIS
# NUEVENTOS
# NUFORINST
# OUV
# PPGEP/CNAT
# PROAD
# PRODES
# PROEN
# PROEX
# PROJU
# PROPI
# PSICOLAR/CNAT
# RE
# SEAC/AP
# SEAC/CA
# SEAC/CAL
# SEAC/CANG
# SEAC/CM
# SEAC/CN
# SEAC/CNAT
# SEAC/IP
# SEAC/JC
# SEAC/LAJ
# SEAC/MC
# SEAC/MO
# SEAC/NC
# SEAC/PAR
# SEAC/PF
# SEAC/SC
# SEAC/SGA
# SEAC/SPP
# SEAC/ZL
# SEAC/ZN
# SEACCON/CNAT
# SEACREN/CNAT
# SEACSUP/CNAT
# SEACTEC/CNAT
# SEC/CNAT
# SEC/RE
# SEPPGEP/CNAT
# nan
# ------------------------------
#
# Total de valores exclusivos para 'funcao': 706
# Exibindo valores exclusivos para coluna 'funcao':
# CD0001 - RE / CD0001 - RE
# CD0002 - DG/AP
# CD0002 - DG/CA
# CD0002 - DG/CAL
# CD0002 - DG/CANG
# CD0002 - DG/CM
# CD0002 - DG/CN
# CD0002 - DG/CNAT
# CD0002 - DG/IP
# CD0002 - DG/JC
# CD0002 - DG/MC
# CD0002 - DG/MO
# CD0002 - DG/NC
# CD0002 - DG/PAR
# CD0002 - DG/PF
# CD0002 - DG/SGA
# CD0002 - DG/SPP
# CD0002 - DG/ZN
# CD0002 - PROAD
# CD0002 - PRODES
# CD0002 - PROEN
# CD0002 - PROEX
# CD0002 - PROPI
# CD0003 - DE/CNAT
# CD0003 - DG/JUC
# CD0003 - DG/LAJ
# CD0003 - DG/PAAS
# CD0003 - DIAC/AP
# CD0003 - DIAC/CAL
# CD0003 - DIAC/CN / SUB-CHEFIA - DG/CN
# CD0003 - DIAC/IP
# CD0003 - DIAC/JC
# CD0003 - DIAC/MC
# CD0003 - DIAC/MO / SUB-CHEFIA - DG/MO
# CD0003 - DIAC/NC
# CD0003 - DIAC/PAR
# CD0003 - DIAC/PF
# CD0003 - DIAC/SC / SUB-CHEFIA - DG/SC
# CD0003 - DIAC/SGA
# CD0003 - DIAC/ZN / SUB-CHEFIA0002 - DG/ZN
# CD0003 - DIAD/CNAT
# CD0003 - DIGAE
# CD0003 - DIGPE
# CD0003 - DIGTI
# CD0003 - GABIN/RE
# CD0003 - PROJU
# CD0004 - ASADM
# CD0004 - ASAES
# CD0004 - ASCE
# CD0004 - ASERI
# CD0004 - AUDGE
# CD0004 - CADIS
# CD0004 - COADPE
# CD0004 - COASS
# CD0004 - CODEPE
# CD0004 - COEDI
# CD0004 - COFIN
# CD0004 - COGCAP
# CD0004 - COINRE
# CD0004 - COMPRO
# CD0004 - COSINF
# CD0004 - DEAD/ZL
# CD0004 - DIAAC
# CD0004 - DIAC/CANG / SUB-CHEFIA - DG/CANG
# CD0004 - DIAC/CM / SUB-CHEFIA - DG/CM
# CD0004 - DIAC/CNAT
# CD0004 - DIAC/JUC
# CD0004 - DIAC/LAJ
# CD0004 - DIAC/PAAS
# CD0004 - DIAC/SPP
# CD0004 - DIAC/ZL
# CD0004 - DIACIN/CNAT
# CD0004 - DIAD/AP
# CD0004 - DIAD/CA
# CD0004 - DIAD/CAL
# CD0004 - DIAD/CANG
# CD0004 - DIAD/CM
# CD0004 - DIAD/CN
# CD0004 - DIAD/JC
# CD0004 - DIAD/MC
# CD0004 - DIAD/MO
# CD0004 - DIAD/NC
# CD0004 - DIAD/PAR
# CD0004 - DIAD/PF
# CD0004 - DIAD/SC
# CD0004 - DIAD/SGA
# CD0004 - DIAD/SPP
# CD0004 - DIAD/ZN
# CD0004 - DIAES/CNAT
# CD0004 - DIAPE/CNAT
# CD0004 - DIARE
# CD0004 - DIAREN/CNAT
# CD0004 - DIATINF/CNAT
# CD0004 - DIENG
# CD0004 - DIGUAE/AP
# CD0004 - DIGUAE/IP
# CD0004 - DIGUIE/CN
# CD0004 - DILIC
# CD0004 - DIPED / SUB-CHEFIA - PROEN
# CD0004 - DIPEQ/CNAT
# CD0004 - DIREX/CNAT
# CD0004 - DITEC
# CD0004 - DTI/CNAT
# CD0004 - GABIN/CNAT
# CD0004 - SEC/RE
# CD2 - DG/SC
# CD3 - DIAC/CA
# CD4 - ASPROC
# CD4 - DIACON/CNAT
# FAA - ASAES/PAAS
# FAA - ASAL/PAAS / FG0001 - COEXPEIN/PAAS
# FAA - ASETEP/PAAS
# FAA4 - COCSEV/ZN
# FACC-IFRN - ACTMIN / FUC0001 - ACTMIN
# FACC-IFRN - ASCTI/PAAS / FUC0001 - CCTI/PAAS
# FACC-IFRN - CCEGA/CNAT
# FACC-IFRN - CCTI/NC / FUC0001 - CCTI/NC
# FACC-IFRN - COESCTAL/CN
# FACC-IFRN - COINF/MO
# FACC-IFRN - DIAC/CNAT
# FACC-IFRN - DIAC/ZL
# FACC-IFRN - DIACIN/CNAT
# FACC-IFRN - DIATINF/CNAT / SUB-CHEFIA4 - DIAC/ZL / SUB-CHEFIA0004 - DEAD/ZL / SUB-CHEFIA - DEAD/ZL
# FACC-IFRN - PROFUNC/ZL / FAG-IFRN - CFORPED/ZL
# FAG-IFRN - AEE/ZL
# FAG-IFRN - AGDE/PRODES
# FAG-IFRN - ASAC/LAJ / FAG-IFRN - SEAC/LAJ
# FAG-IFRN - ASAC/PAAS
# FAG-IFRN - ASAES/LAJ
# FAG-IFRN - ASBIB/LAJ
# FAG-IFRN - ASCAAT
# FAG-IFRN - ASET/CNAT
# FAG-IFRN - ASFPAG
# FAG-IFRN - ASGPE/LAJ
# FAG-IFRN - ASGPE/PAAS
# FAG-IFRN - ASGRIS/DIGPE
# FAG-IFRN - ASGTIC
# FAG-IFRN - ASIT/ZL
# FAG-IFRN - ASLAB/LAJ
# FAG-IFRN - ASREMT
# FAG-IFRN - ASRINT/CNAT
# FAG-IFRN - ASSEL
# FAG-IFRN - ASTE/ZL
# FAG-IFRN - CAPROM/ZL / SUB-CHEFIA - COTEFIC/ZL / SUB-CHEFIA - DIAC/ZL / CD3 - DG/ZL / FAG-IFRN - CESPPA/ZL
# FAG-IFRN - CCEDISB/SGA
# FAG-IFRN - CCEEC
# FAG-IFRN - CECINAM/AP
# FAG-IFRN - CEECNEB/JC
# FAG-IFRN - CENTEC/CM
# FAG-IFRN - CESPEI
# FAG-IFRN - CESPEM/ZL
# FAG-IFRN - CESPGP/ZL
# FAG-IFRN - CESPLPM/ZL
# FAG-IFRN - CESPTEED/ZL
# FAG-IFRN - CFOREAD/ZL
# FAG-IFRN - CLICESP/ZL
# FAG-IFRN - CLING/CNAT
# FAG-IFRN - COAES/ZL
# FAG-IFRN - COAGRO/AP
# FAG-IFRN - COCINF/CM
# FAG-IFRN - COCOMP/PAR / SUB-CHEFIA - DIAD/PAR
# FAG-IFRN - COCOMP/ZN
# FAG-IFRN - COCSEV/CAL
# FAG-IFRN - COCSEV/IP
# FAG-IFRN - COCSEV/JC
# FAG-IFRN - COCSEV/PAR
# FAG-IFRN - CODIFG/PAR
# FAG-IFRN - COESET/PAR
# FAG-IFRN - COESP/CM
# FAG-IFRN - COESP/PAR
# FAG-IFRN - COEX/CAL
# FAG-IFRN - COEX/IP
# FAG-IFRN - COEX/MO
# FAG-IFRN - COEXPEIN/ZL / FAG-IFRN - COTEFIC/ZL
# FAG-IFRN - COFISCOB/RE
# FAG-IFRN - COGEAM/MO
# FAG-IFRN - COLIC/DILIC
# FAG-IFRN - COLIQ/AP / FUC1 - COLIQ/AP
# FAG-IFRN - COMUMI/CNAT
# FAG-IFRN - COORD_FIC/CANG
# FAG-IFRN - COORD_LEDOC
# FAG-IFRN - COORD_POS_GRAD
# FAG-IFRN - COPAD/PAR
# FAG-IFRN - COPEIN/MO
# FAG-IFRN - COPEIN/PAR / SUB-CHEFIA - COPEIN/PAR
# FAG-IFRN - COPJODIG/CM
# FAG-IFRN - CTECGA/ZL
# FAG-IFRN - CTECII/ZL
# FAG-IFRN - CTMS/AP
# FAG-IFRN - DG/CAL / FG0001 - COPEIN/CAL
# FAG-IFRN - DIAC/CAL
# FAG-IFRN - DIAC/JC
# FAG-IFRN - DIAC/MC
# FAG-IFRN - DIAC/PAR
# FAG-IFRN - DIAC/SGA
# FAG-IFRN - DIAC/SPP
# FAG-IFRN - DIAC/ZL / FUC0001 - CCLOGCS/SGA
# FAG-IFRN - DIAD/LAJ
# FAG-IFRN - DITEC
# FAG-IFRN - GABIN/RE
# FAG-IFRN - NAE/MC / SUB-CHEFIA - DIGUIE/MC / FG0001 - DIGUIE/MC
# FAG-IFRN - NAPNE/CAL
# FAG-IFRN - NUARTE/CNAT
# FAG-IFRN - NUJOR
# FAG-IFRN - OUV
# FAG-IFRN - PRODES
# FAG-IFRN - PROEX
# FAG-IFRN - PROPI
# FAG-IFRN - QVT/MC
# FAG-IFRN - UAB/IFRN / FAG-IFRN - CESPEJA/ZL
# FAG-IFRN - UAB/IFRN / FAG-IFRN - CESPEP/ZL
# FAG-IFRN - UGI
# FG - CEE/MO
# FG - COAPAC/SPP
# FG - COCMEN/MO
# FG - COCSEV/SGA
# FG - COEDU/MO
# FG - COMULT/MO
# FG - SEAC/MO / SUB-CHEFIA - COCSEV/MO
# FG0001 -
# FG0001 -  / SUB-CHEFIA - DIAC/JC
# FG0001 - ASTEC
# FG0001 - CASEM/CNAT
# FG0001 - CME/ZL
# FG0001 - COAES/MO
# FG0001 - COAPAT
# FG0001 - COAS/CNAT
# FG0001 - COCAP/CNAT
# FG0001 - COCSEV/CNAT
# FG0001 - CODEPE/CNAT
# FG0001 - COEX/AP
# FG0001 - COEX/CA
# FG0001 - COEX/CAL
# FG0001 - COEX/CANG / SUB-CHEFIA - GABIN/CANG
# FG0001 - COEX/CM
# FG0001 - COEX/CN
# FG0001 - COEX/IP
# FG0001 - COEX/MC
# FG0001 - COEX/MO
# FG0001 - COEX/NC
# FG0001 - COEX/PAR
# FG0001 - COEX/PF
# FG0001 - COEX/SC
# FG0001 - COEX/SGA
# FG0001 - COEX/SPP
# FG0001 - COEX/ZN
# FG0001 - COEXPEIN/LAJ  / SUB-CHEFIA - DG/LAJ
# FG0001 - COEXPEIN/PAAS
# FG0001 - COFIN/CNAT
# FG0001 - COGPE/MO
# FG0001 - COPED/CNAT
# FG0001 - COPEIN/AP
# FG0001 - COPEIN/CA
# FG0001 - COPEIN/CANG
# FG0001 - COPEIN/CM
# FG0001 - COPEIN/CN
# FG0001 - COPEIN/IP / SUB-CHEFIA - COEX/IP
# FG0001 - COPEIN/JC
# FG0001 - COPEIN/MC
# FG0001 - COPEIN/MO
# FG0001 - COPEIN/NC
# FG0001 - COPEIN/PAR / SUB-CHEFIA001 - COEX/PAR
# FG0001 - COPEIN/PF
# FG0001 - COPEIN/SC
# FG0001 - COPEIN/SGA
# FG0001 - COPEIN/SPP
# FG0001 - COPEIN/ZN / SUB-CHEFIA0002 - DG/ZN
# FG0001 - COSAAD
# FG0001 - COSAEN
# FG0001 - COSGEM/AP
# FG0001 - COSGEM/CA
# FG0001 - COSGEM/CAL
# FG0001 - COSGEM/CANG / SUB-CHEFIA - DIAD/CANG
# FG0001 - COSGEM/CM
# FG0001 - COSGEM/CN
# FG0001 - COSGEM/IP
# FG0001 - COSGEM/JC
# FG0001 - COSGEM/MC
# FG0001 - COSGEM/MO
# FG0001 - COSGEM/PAR
# FG0001 - COSGEM/PF
# FG0001 - COSGEM/SC
# FG0001 - COSGEM/SGA
# FG0001 - COSGEM/SPP
# FG0001 - COSGEM/ZN
# FG0001 - CRA/CNAT
# FG0001 - CTI/MO
# FG0001 - CTI/ZL
# FG0001 - DIAD/LAJ
# FG0001 - DIAD/PAAS
# FG0001 - DIGUIE/PF
# FG0001 - GABIN/AP
# FG0001 - GABIN/CA
# FG0001 - GABIN/CM
# FG0001 - GABIN/CN
# FG0001 - GABIN/IP
# FG0001 - GABIN/JC
# FG0001 - GABIN/LAJ
# FG0001 - GABIN/MC
# FG0001 - GABIN/MO
# FG0001 - GABIN/NC
# FG0001 - GABIN/PAR
# FG0001 - GABIN/PF
# FG0001 - GABIN/SC
# FG0001 - GABIN/SGA
# FG0001 - GABIN/SPP
# FG0001 - GABIN/ZL
# FG0001 - GABIN/ZN
# FG0001 - NAPNE/AP
# FG0001 - NAPNE/CA
# FG0001 - NAPNE/CAL
# FG0001 - NAPNE/CANG
# FG0001 - NAPNE/CM
# FG0001 - NAPNE/CN
# FG0001 - NAPNE/CNAT
# FG0001 - NAPNE/IP
# FG0001 - NAPNE/LAJ
# FG0001 - NAPNE/MC
# FG0001 - NAPNE/MO
# FG0001 - NAPNE/PAAS
# FG0001 - NAPNE/PAR
# FG0001 - NAPNE/PF
# FG0001 - NAPNE/SC
# FG0001 - NAPNE/SGA
# FG0001 - NAPNE/SPP
# FG0001 - NAPNE/ZL
# FG0001 - NAPNE/ZN
# FG0001 - SEAC/CNAT
# FG0002 - CALMOX/CNAT
# FG0002 - COADES/CNAT
# FG0002 - COADES/MO
# FG0002 - COADS
# FG0002 - COAES/AP
# FG0002 - COAES/CA
# FG0002 - COAES/CANG
# FG0002 - COAES/IP
# FG0002 - COAES/JC
# FG0002 - COAES/MC
# FG0002 - COAES/PAR
# FG0002 - COAES/PF
# FG0002 - COAES/SC
# FG0002 - COAES/SGA
# FG0002 - COAES/SPP
# FG0002 - COAES/ZN
# FG0002 - COAPAC/AP / SUB-CHEFIA - DIAC/AP / SUB-CHEFIA - DG/AP
# FG0002 - COAPAC/CA
# FG0002 - COAPAC/CAL
# FG0002 - COAPAC/CANG
# FG0002 - COAPAC/CM
# FG0002 - COAPAC/CN
# FG0002 - COAPAC/IP
# FG0002 - COAPAC/JC
# FG0002 - COAPAC/MC
# FG0002 - COAPAC/NC / SUB-CHEFIA2 - GABIN/NC
# FG0002 - COAPAC/PAR / SUB-CHEFIA1 - GABIN/PAR
# FG0002 - COAPAC/PF
# FG0002 - COAPAC/SGA
# FG0002 - COAPAC/ZN
# FG0002 - COBIB/CNAT
# FG0002 - COCOMP/CNAT
# FG0002 - CODESP/CNAT
# FG0002 - COEB/CNAT
# FG0002 - COESUP/CNAT
# FG0002 - COFIMPAT/LAJ
# FG0002 - COFIMPAT/PAAS
# FG0002 - COFINC/AP
# FG0002 - COFINC/CA
# FG0002 - COFINC/CAL / SUB-CHEFIA - DG/CAL
# FG0002 - COFINC/CANG
# FG0002 - COFINC/CM
# FG0002 - COFINC/CN
# FG0002 - COFINC/JC
# FG0002 - COFINC/MC
# FG0002 - COFINC/MO / SUB-CHEFIA - DIAD/MO
# FG0002 - COFINC/NC
# FG0002 - COFINC/PAR
# FG0002 - COFINC/PF
# FG0002 - COFINC/SGA
# FG0002 - COFINC/ZN
# FG0002 - COGPE/AP
# FG0002 - COGPE/CA
# FG0002 - COGPE/CAL
# FG0002 - COGPE/CM
# FG0002 - COGPE/CN
# FG0002 - COGPE/IP
# FG0002 - COGPE/JC
# FG0002 - COGPE/MC
# FG0002 - COGPE/NC
# FG0002 - COGPE/PAR
# FG0002 - COGPE/PF
# FG0002 - COGPE/SC
# FG0002 - COGPE/SGA
# FG0002 - COGPE/SPP
# FG0002 - COGPE/ZN
# FG0002 - COLAB/AP
# FG0002 - COLAB/CA
# FG0002 - COLAB/CAL
# FG0002 - COLAB/CANG
# FG0002 - COLAB/CM
# FG0002 - COLAB/CN
# FG0002 - COLAB/IP
# FG0002 - COLAB/JC
# FG0002 - COLAB/MC
# FG0002 - COLAB/MO
# FG0002 - COLAB/NC
# FG0002 - COLAB/PF
# FG0002 - COLAB/SC
# FG0002 - COLAB/SGA
# FG0002 - COLAB/SPP
# FG0002 - COLAB/ZN
# FG0002 - COLABCI/CNAT
# FG0002 - COLABIND/CNAT
# FG0002 - COLABINF/CNAT
# FG0002 - COLABREN/CNAT
# FG0002 - COLURB/CNAT
# FG0002 - COMPAT/AP
# FG0002 - COMPAT/CA
# FG0002 - COMPAT/CAL
# FG0002 - COMPAT/CANG
# FG0002 - COMPAT/CM
# FG0002 - COMPAT/CN
# FG0002 - COMPAT/IP
# FG0002 - COMPAT/JC
# FG0002 - COMPAT/MC
# FG0002 - COMPAT/MO
# FG0002 - COMPAT/NC
# FG0002 - COMPAT/PAR
# FG0002 - COMPAT/PF
# FG0002 - COMPAT/SC
# FG0002 - COMPAT/SPP
# FG0002 - COMPAT/ZN / FG2 - COMPAT/ZN
# FG0002 - COMULT/CNAT
# FG0002 - CONC/CNAT
# FG0002 - COPAT/CNAT
# FG0002 - COPLAV
# FG0002 - COPREC/CNAT
# FG0002 - COSEG/CNAT
# FG0002 - CSAUDE/CNAT
# FG0002 - CTI/AP
# FG0002 - CTI/CAL
# FG0002 - CTI/CANG
# FG0002 - CTI/CM
# FG0002 - CTI/CN
# FG0002 - CTI/IP
# FG0002 - CTI/JC
# FG0002 - CTI/MC
# FG0002 - CTI/NC
# FG0002 - CTI/PAR
# FG0002 - CTI/PF
# FG0002 - CTI/SC
# FG0002 - CTI/SGA
# FG0002 - CTI/SPP
# FG0002 - CTI/ZN
# FG0002 - DIAD/PAAS
# FG0002 - DIAD/ZL
# FG0002 - GABIN/JUC
# FG0002 - PROJU
# FG0002 - SEAC/CA
# FG0002 - SEAC/CAL
# FG0002 - SEAC/CANG
# FG0002 - SEAC/CM
# FG0002 - SEAC/CN
# FG0002 - SEAC/JC
# FG0002 - SEAC/MC / SUB-CHEFIA - COMPAT/MC
# FG0002 - SEAC/NC
# FG0002 - SEAC/PAR
# FG0002 - SEAC/PF
# FG0002 - SEAC/SC / SUB-CHEFIA - DIAC/SC
# FG0002 - SEAC/SGA
# FG0002 - SEAC/SPP
# FG0002 - SEAC/ZL
# FG0002 - SEAC/ZN
# FG0002 - SEACSUP/CNAT
# FG0002 - SEACTEC/CNAT
# FG0002 - SEC/CNAT
# FG1 - COCAB/CNAT
# FG1 - GABIN/CANG / FAG-IFRN1 - COCSEV/CANG
# FG1 - GABIN/PAAS
# FG2 -
# FG2 - COAPAC/SC
# FG2 - COFINC/SC / CD - DIAD/SC
# FG2 - COLABCON/CNAT
# FG2 - SEAC/AP / FG0002 - SEAC/AP
# FG4 - COFIMPAT/ZL
# FUC - COPPgUSRN/CNAT
# FUC0001 -
# FUC0001 - CCAGEN/ZN
# FUC0001 - CCEDIIT/SGA
# FUC0001 - CCELT/ZN / SUB-CHEFIA0003 - DIAC/ZN
# FUC0001 - CCENGPRO/SGA
# FUC0001 - CCESA
# FUC0001 - CCINFIT/SGA
# FUC0001 - CCLOGIT/SGA
# FUC0001 - CCREDCS/SGA
# FUC0001 - CCTCA/CNAT
# FUC0001 - CCTG/CNAT
# FUC0001 - CCTGA/CNAT
# FUC0001 - CCTI/CNAT
# FUC0001 - CCTM/CNAT
# FUC0001 - CCTST/CNAT
# FUC0001 - CEEST/CNAT
# FUC0001 - CLIESP/CNAT
# FUC0001 - CLIFIS/CNAT
# FUC0001 - CLIGEO/CNAT
# FUC0001 - CLIMAT/CM
# FUC0001 - CLIMAT/CNAT
# FUC0001 - CLINF/IP
# FUC0001 - CLINF/ZN
# FUC0001 - CLIPE/CNAT
# FUC0001 - CLQ/CN
# FUC0001 - COAPIC/PF
# FUC0001 - COBIO/AP
# FUC0001 - COBIO/MC
# FUC0001 - COCADM/LAJ
# FUC0001 - COCINF/IP
# FUC0001 - COCINF/LAJ
# FUC0001 - COCOM/LAJ
# FUC0001 - COCTADM/CNAT
# FUC0001 - COCTADM/NC
# FUC0001 - COCTECBIO/CM
# FUC0001 - COEDI/MO
# FUC0001 - COELE/MO
# FUC0001 - COENGCIV
# FUC0001 - COEVENTOS/CAL
# FUC0001 - COFORPED/PAR
# FUC0001 - COGDL/CAL
# FUC0001 - COGTURISMO/CAL
# FUC0001 - COIN/JUC
# FUC0001 - COINF/MO
# FUC0001 - COLAZER/CAL
# FUC0001 - COLIQ/PF
# FUC0001 - COMAMB/IP
# FUC0001 - COMAT/MO
# FUC0001 - COMEC/MO
# FUC0001 - COMNPEF/CNAT
# FUC0001 - COMULTIMIDIA
# FUC0001 - COORDELETRO/CNA
# FUC0001 - COORDENG/CNAT / CD - DIACIN/CNAT
# FUC0001 - COORDPETRO/CNAT
# FUC0001 - COORD_ELETRO
# FUC0001 - COORD_EVEN_INT
# FUC0001 - COORD_GESTUR
# FUC0001 - COORD_INFO/CANG
# FUC0001 - COORD_LEDOC
# FUC0001 - COORD_MEC/CANG
# FUC0001 - COORD_SISTIN
# FUC0001 - COPET/MO
# FUC0001 - COPROQ/MC
# FUC0001 - COQUIM/MC
# FUC0001 - COREP/MC
# FUC0001 - COSAN/MO
# FUC0001 - COTADS/CNAT
# FUC0001 - COTADS/NC
# FUC0001 - COTADS/PF
# FUC0001 - COTECEDI/DIACON
# FUC0001 - COTEDIF/CNAT
# FUC0001 - COTEQ/AP
# FUC0001 - CSAL/CN
# FUC0001 - CSTEMK/ZN
# FUC0001 - CTAGRO/IP
# FUC0001 - CTAGROI/PF
# FUC0001 - CTAL/PF
# FUC0001 - CTECPROQ/NC
# FUC0001 - CTECQ/NC
# FUC0001 - CTECTEX/CA
# FUC0001 - CTGPUBLICA/CNAT
# FUC0001 - CTINF/CN
# FUC0001 - CTINF/PAR
# FUC0001 - CTINF/PF
# FUC0001 - CTINF/ZN
# FUC0001 - CTMEC/SC
# FUC0001 - CTMECAT/PAR
# FUC0001 - CTMS-EJA/AP
# FUC0001 - CTMS/CM
# FUC0001 - CTMS/CN / SUB-CHEFIA - DIAC/CN
# FUC0001 - CTMS/CNAT
# FUC0001 - CTMS/SC
# FUC0001 - CTMS/ZN
# FUC0001 - CTRECOMP/CNAT
# FUC0001 - CTRECOMP/PAR
# FUC0001 - CTRFG/SC
# FUC0001 - CTSI/PAR / SUB-CHEFIA - DIAC/PAR
# FUC0001 - Coordmec/CNAT
# FUC0001 - DIAC/AP
# FUC0001 - DIAC/CA
# FUC0001 - DIAC/IP
# FUC0001 - DIAC/JC
# FUC0001 - DIAC/MC
# FUC0001 - DIAC/SC
# FUC0001 - DIAC/SPP
# FUC0001 - DIATINF/CNAT
# FUC1 - COTEST/DIACON
# FUC1 - DIAC/CN
# FUC1 - PROFEPT
# SUB-CHEFIA - CEE/CNAT / FG0002 - CEE/CNAT
# SUB-CHEFIA - COADPE
# SUB-CHEFIA - COAES/CAL
# SUB-CHEFIA - COAES/CAL / FG0002 - COAES/CAL
# SUB-CHEFIA - COAES/CANG
# SUB-CHEFIA - COAES/CN / FG0002 - COAES/CN
# SUB-CHEFIA - COAES/MC
# SUB-CHEFIA - COAES/MO
# SUB-CHEFIA - COAES/NC
# SUB-CHEFIA - COAES/PAR
# SUB-CHEFIA - COAES/SGA
# SUB-CHEFIA - COAPAC/AP
# SUB-CHEFIA - COAPAC/CANG
# SUB-CHEFIA - COAPAC/NC
# SUB-CHEFIA - COBIB/MO
# SUB-CHEFIA - COBIB/MO / FG0002 - COBIB/MO
# SUB-CHEFIA - COCSEV/AP
# SUB-CHEFIA - COCSEV/CAL / FAG-IFRN - NUDESIGN
# SUB-CHEFIA - COCSEV/SGA
# SUB-CHEFIA - COEVENTOS/CAL
# SUB-CHEFIA - COEX/AP
# SUB-CHEFIA - COEX/CAL / FAG-IFRN - COAES/CAL
# SUB-CHEFIA - COEX/CANG / FAG-IFRN - ARI/COEX/CANG
# SUB-CHEFIA - COEX/NC / SUB-CHEFIA - COMPAT/NC / FG - COAES/NC / FG0002 - COAES/NC
# SUB-CHEFIA - COFINC/AP
# SUB-CHEFIA - COFINC/CAL
# SUB-CHEFIA - COFINC/IP / FG0002 - COFINC/IP
# SUB-CHEFIA - COFINC/SC
# SUB-CHEFIA - COFINC/SGA
# SUB-CHEFIA - COFINC/SPP / FG0002 - COFINC/SPP
# SUB-CHEFIA - COGPE/AP
# SUB-CHEFIA - COGPE/CA
# SUB-CHEFIA - COGPE/CAL
# SUB-CHEFIA - COGPE/MC / FG0002 - COGPE/CANG
# SUB-CHEFIA - COGPE/MO
# SUB-CHEFIA - COGPE/SGA
# SUB-CHEFIA - COLAB/AP
# SUB-CHEFIA - COLAB/CAL
# SUB-CHEFIA - COLAB/CN / SUB-CHEFIA - COEX/CN
# SUB-CHEFIA - COLAB/MC
# SUB-CHEFIA - COLAB/MO
# SUB-CHEFIA - COLAB/SC
# SUB-CHEFIA - COLAB/SGA
# SUB-CHEFIA - COLAZER/CAL
# SUB-CHEFIA - COMPAT/AP
# SUB-CHEFIA - COMPAT/CAL
# SUB-CHEFIA - COMPAT/CANG / SUB-CHEFIA - COGPE/CANG
# SUB-CHEFIA - COMPAT/CN
# SUB-CHEFIA - COMPAT/PAR
# SUB-CHEFIA - COMPAT/SC
# SUB-CHEFIA - COMPAT/SGA
# SUB-CHEFIA - COMPAT/SGA / SUB-CHEFIA - SEAC/SGA / FG0002 - COMPAT/SGA
# SUB-CHEFIA - COMULT/SGA
# SUB-CHEFIA - COMULTIMIDIA
# SUB-CHEFIA - COPED/CNAT
# SUB-CHEFIA - COPEIN/JC
# SUB-CHEFIA - COPEIN/MO
# SUB-CHEFIA - COPEIN/SGA
# SUB-CHEFIA - COSGEM/AP
# SUB-CHEFIA - COSGEM/CAL
# SUB-CHEFIA - COSGEM/CANG
# SUB-CHEFIA - COSGEM/PAR
# SUB-CHEFIA - COSGEM/SGA
# SUB-CHEFIA - CTI/AP
# SUB-CHEFIA - CTI/CAL
# SUB-CHEFIA - CTI/CANG
# SUB-CHEFIA - CTI/MO
# SUB-CHEFIA - CTI/NC
# SUB-CHEFIA - CTI/SC
# SUB-CHEFIA - CTI/SGA
# SUB-CHEFIA - DG/NC
# SUB-CHEFIA - DG/NC / CD0004 - DIAD/NC
# SUB-CHEFIA - DG/PAR
# SUB-CHEFIA - DG/SGA
# SUB-CHEFIA - DG/SPP / SUB-CHEFIA - COFINC/SPP
# SUB-CHEFIA - DIAC/CANG
# SUB-CHEFIA - DIAC/MC / SUB-CHEFIA - DG/MC
# SUB-CHEFIA - DIAC/MO / FG0002 - COCSEV/MO
# SUB-CHEFIA - DIAD/AP
# SUB-CHEFIA - DIAD/CAL
# SUB-CHEFIA - DIAD/CANG
# SUB-CHEFIA - DIAD/CNAT
# SUB-CHEFIA - DIAD/IP / CD0004 - DIAD/IP
# SUB-CHEFIA - DIAD/JC
# SUB-CHEFIA - DIAD/MC
# SUB-CHEFIA - DIAD/NC / FG0001 - COSGEM/NC
# SUB-CHEFIA - DIAD/SGA
# SUB-CHEFIA - DIAD/SPP
# SUB-CHEFIA - DIAPAC/MO
# SUB-CHEFIA - DIAPAC/MO / CD0004 - DIAPAC/MO
# SUB-CHEFIA - DIGPE
# SUB-CHEFIA - DIGUAE/AP
# SUB-CHEFIA - GABIN/AP / SUB-CHEFIA - COPEIN/AP
# SUB-CHEFIA - GABIN/CA
# SUB-CHEFIA - GABIN/CAL
# SUB-CHEFIA - GABIN/CAL / FG0001 - GABIN/CAL
# SUB-CHEFIA - GABIN/CN
# SUB-CHEFIA - GABIN/SGA
# SUB-CHEFIA - SEAC/AP
# SUB-CHEFIA - SEAC/IP / FG0002 - SEAC/IP
# SUB-CHEFIA - SEAC/SPP
# SUB-CHEFIA0001 - CME/ZL
# SUB-CHEFIA0002 - COFINC/ZN
# SUB-CHEFIA0002 - COLAB/ZN
# SUB-CHEFIA0002 - COMPAT/ZN
# SUB-CHEFIA0002 - COPAT/CNAT
# SUB-CHEFIA0002 - CTI/ZN
# SUB-CHEFIA2 - SEAC/PAR
# SUB-CHEFIACD-4 - COASS
# SUB-CHEFIAFG-1 - COAS/CNAT
# SUB-CHEFIAFG-1 - COLABCON/CNAT
# nan
# ------------------------------
#
# Total de valores exclusivos para 'jornada_trabalho': 5
# Exibindo valores exclusivos para coluna 'jornada_trabalho':
# 20 HORAS SEMANAIS
# 25 HORAS SEMANAIS
# 30 HORAS SEMANAIS
# 40 HORAS SEMANAIS
# DEDICACAO EXCLUSIVA
# ------------------------------
#
# Total de valores exclusivos para 'campus': 23
# Exibindo valores exclusivos para coluna 'campus':
# AP
# CA
# CAL
# CANG
# CM
# CN
# CNAT
# IP
# JC
# JUC
# LAJ
# MC
# MO
# NC
# PAAS
# PAR
# PF
# RE
# SC
# SGA
# SPP
# ZL
# ZN
# ------------------------------

# %%
# @title --- 3. Tratamento dos parâmentos de colunas de interesse ---
# --- 3.1. Tratamento da Coluna 'categoria' ---
# Para melhor visualização em ferramentas de BI, vamos padronizar os textos.
print("Tratando a coluna 'categoria'...")
mapeamento_categoria = {
    'docente': 'Docente',
    'tecnico_administrativo': 'Técnico Administrativo',
    'estagiario': 'Estagiário',
    'indefinida': 'Não Definida' # Garante que valores indefinidos sejam claros.
}
df['categoria_tratada'] = df['categoria'].map(mapeamento_categoria).fillna('Outros')
print("Valores únicos em 'categoria_tratada':")
print(df['categoria_tratada'].unique())
print("-" * 50)

# --- 3.2. Tratamento da Coluna 'campus' ---
# Substituir as siglas por nomes completos torna os filtros e gráficos no BI mais intuitivos.
print("Tratando a coluna 'campus'...")
mapeamento_campus = {
    'AP': 'Apodi',
    'CA': 'Caicó',
    'CAL': 'Natal - Cidade Alta',
    'CANG': 'Canguaretama',
    'CM': 'Ceará-Mirim',
    'CN': 'Currais Novos',
    'CNAT': 'Natal - Central',
    'IP': 'Ipanguaçu',
    'JC': 'João Câmara',
    'JUC': 'Jucurutu',
    'LAJ': 'Lajes',
    'MC': 'Macau',
    'MO': 'Mossoró',
    'NC': 'Nova Cruz',
    'PAAS': 'Parelhas',
    'PAR': 'Parnamirim',
    'PF': 'Pau dos Ferros',
    'RE': 'Reitoria',
    'SC': 'Santa Cruz',
    'SGA': 'São Gonçalo do Amarante',
    'SPP': 'São Paulo do Potengi',
    'ZL': 'Natal - Zona Leste',
    'ZN': 'Natal - Zona Norte'
}
df['campus_tratado'] = df['campus'].map(mapeamento_campus).fillna('Não Identificado')
print("Valores únicos em 'campus_tratado':")
# Mostra os valores únicos ordenados para fácil verificação
print(sorted(df['campus_tratado'].unique()))
print("-" * 50)

# --- 3.3. Tratamento da Coluna 'setor_suap' (Aperfeiçoado) ---
# Implementando a lógica sugerida para remover a redundância do campus.
print("Tratando a coluna 'setor_suap' com a lógica aperfeiçoada...")
print(f"Valores únicos antes do tratamento: {df['setor_suap'].nunique()}")

# Usamos .astype(str) para evitar erros com valores nulos (NaN)
# e aplicamos a sua lógica para dividir a string e pegar a primeira parte.
df['setor_tratado'] = df['setor_suap'].astype(str).str.split('/').str[0]

# Substituímos o valor 'nan' (que vem de células vazias) por um texto claro.
df['setor_tratado'] = df['setor_tratado'].replace('nan', 'Setor Não Informado')

print(f"Valores únicos após o tratamento: {df['setor_tratado'].nunique()}")
print("Exemplo de transformação:")
print(df[['setor_suap', 'setor_tratado']].head())
print("-" * 50)

# --- 3.4. Tratamento da Coluna 'funcao' ---
# Removendo a descrição detalhada da função para manter apenas o código/título.
print("Tratando a coluna 'funcao'...")
df['funcao_tratado'] = df['funcao'].astype(str).str.split(' - ').str[0]
# Código corrigido para evitar o FutureWarning
df['funcao_tratado'] = df['funcao_tratado'].replace('nan', 'Sem Função')
print("Exemplo de transformação da coluna 'funcao':")
# Mostra as linhas que de fato possuem uma função para um melhor exemplo
print(df[df['funcao'].notna()][['funcao', 'funcao_tratado']].head())
print("-" * 50)

# --- 3.5. Tratamento da Coluna 'jornada_trabalho' ---
print("Tratando a coluna 'jornada_trabalho'...")
mapeamento_jornada = {
    '20 HORAS SEMANAIS': '20h Semanais',
    '25 HORAS SEMANAIS': '25h Semanais',
    '30 HORAS SEMANAIS': '30h Semanais',
    '40 HORAS SEMANAIS': '40h Semanais',
    'DEDICACAO EXCLUSIVA': 'Dedicação Exclusiva'
}
df['jornada_tratada'] = df['jornada_trabalho'].map(mapeamento_jornada).fillna('Não Informada')
print("Exemplo de transformação da coluna 'jornada_trabalho':")
print(df[['jornada_trabalho', 'jornada_tratada']].head())
print("-" * 50)

# --- 3.6. Tratamento da Coluna 'disciplina_ingresso' ---
print("Tratando a coluna 'disciplina_ingresso'...")
# Primeiro, preenchemos os valores nulos (NaN) e '-' com uma string única para facilitar a substituição.
df['disciplina_tratada'] = df['disciplina_ingresso'].fillna('N/A').replace('-', 'N/A')

# Para servidores que não são docentes, a disciplina de ingresso não se aplica.
# Usamos np.where para aplicar essa lógica condicional.
df['disciplina_tratada'] = np.where(
    df['categoria_tratada'] != 'Docente',
    'Não se Aplica',
    df['disciplina_tratada']
)

# Para docentes que possam ter ficado com 'N/A', trocamos por um texto mais claro.
df['disciplina_tratada'] = df['disciplina_tratada'].replace('N/A', 'Disciplina Não Informada')

print("Exemplo de transformação da coluna 'disciplina_ingresso':")
print(df[['categoria_tratada', 'disciplina_ingresso', 'disciplina_tratada']].head(10))
print("-" * 50)

# --- 3.7. Função para padronização da coluna 'Cargos' ---
def padronizar_cargos(df_column):
    """
    Padroniza os nomes dos cargos para agrupar funções semelhantes e corrigir inconsistências.
    """

    # 1. Agrupamento inicial com regex
    mapeamento_cargos = {
        # Agrupamento de Professores
        r'.*PROFESSOR.*': 'Professor do EBTT',
        r'.*PROF.*': 'Professor do EBTT',
        # 'PROF DO ENSINO BASICO TEC TECNOLOGICO', 'PROF ENS BAS TEC TECNOLOGICO - VISITANTE',
        # 'PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO', 'PROFESSOR ENS BASICO TECN TECNOLOGICO'

        # Padronização de Cargos Técnicos e Administrativos (removendo sufixos)
        #'TECNICO DE LABORATORIO AREA': 'Técnico de Laboratório',
        'DESENHISTA-PROJETISTA': 'Desenhista Projetista',
        'TEC EM SEGURANCA DO TRABALHO': 'Técnico em Segurança do Trabalho',
        'TEC EM METROLOGIA E QUALIDADE': 'Técnico em Metrologia e Qualidade',
        'ENGENHEIRO DE SEG DO TRABALHO': 'Engenheiro de Segurança do Trabalho',
        'OPERADOR DE MAQ DE LAVANDERIA': 'Operador de Máquina de Lavanderia',
        # 'TECNOLOGO-FORMACAO': 'Tecnólogo',
        'NUTRICIONISTA-HABILITACAO': 'Nutricionista/habilitação',
        'BIBLIOTECARIO-DOCUMENTALISTA': 'Bibliotecário',
        'ANALISTA DE TEC DA INFORMACAO': 'Analista de Tecnologia da Informação',
        'TEC DE TECNOLOGIA DA INFORMACAO': 'Técnico de Tecnologia da Informação',
        'ODONTOLOGO - 30H - DEC JUD': 'Odontólogo',
        'ODONTOLOGO - 40 HORAS': 'Odontólogo',

        # Agrupamento de Estagiários
        r'.*ESTAGIARIO.*': 'Estagiário',
        # 'ESTAGIARIO DE NIVEL SUPERIOR', 'ESTAGIARIO JORNADA 30 HORAS', 'ESTAGIARIO NIVEL MEDIO - INPE'

        # Correções pontuais
        'AUX EM ADMINISTRACAO': 'Auxiliar em Administração',
        # 'ASSISTENTE EM ADMINISTRACAO': 'Assistente em Administração',
        'TRADUTOR INTERPRETE DE LINGUAGEM SINAIS': 'Tradutor e Intérprete de Linguagem de Sinais'
    }

    # Aplica o mapeamento com regex
    cargo_tratado = df_column.astype(str).replace(mapeamento_cargos, regex=True)

    # Remove o sufixo '-AREA'
    cargo_tratado = cargo_tratado.str.replace('-AREA', '/área', regex=False)
    cargo_tratado = cargo_tratado.str.replace(' AREA', '/área', regex=False)
    cargo_tratado = cargo_tratado.str.replace('-FORMACAO', '/formação', regex=False)

    # Converte para o formato Título (Primeira Letra Maiúscula) e remove espaços extras
    cargo_tratado = cargo_tratado.str.title().str.strip()

        # 3. Mapeamento para acentuação e correções finais
    mapeamento_acentos = {
        'Administracao': 'Administração',
        'Agropecuaria': 'Agropecuária',
        'Agronomo': 'Agrônomo',
        'Edificacoes': 'Edificações',
        'Eletrotecnica': 'Eletrotécnica',
        'Estatistico': 'Estatístico',
        'Fisico': 'Físico',
        'Graficas': 'Gráficas',
        'Laboratorio': 'Laboratório',
        'Laticinios': 'Laticínios',
        'Mecanica': 'Mecânica',
        'Mecanico': 'Mecânico',
        'Medico': 'Médico',
        'Mineracao': 'Mineração',
        'Veterinario': 'Veterinário',
        'Publicitario': 'Publicitário',
        'Psicologo': 'Psicólogo',
        'Quimica': 'Química',
        'Tecnico': 'Técnico'
    }

    # Aplica as substituições de acentuação
    for termo, correto in mapeamento_acentos.items():
        cargo_tratado = cargo_tratado.str.replace(termo, correto, regex=False)

    # Padroniza conectivos em minúsculas após a capitalização
    cargo_tratado = cargo_tratado.str.replace(r'\b(Da|Do|De|E|Em)\b', lambda m: m.group(1).lower(), regex=True)

    # Trata valores nulos ou vazios que restaram
    cargo_tratado = cargo_tratado.replace(['Nan', ''], 'Não Informado')

    return cargo_tratado

# Aplica a função de padronização de cargos
df['cargo_tratado'] = padronizar_cargos(df['cargo'])

print("Exemplo de transformação da coluna 'cargo':")
print(df[['cargo', 'cargo_tratado']].head(10))
print("-" * 50)

# Inclui a coluna 'Ano' a partir de 'last_updated_date'
df['Ano'] = data # Corrigido para usar a variável 'data' formatada
# Out:
# Tratando a coluna 'categoria'...
# Valores únicos em 'categoria_tratada':
# ['Docente' 'Técnico Administrativo' 'Estagiário' 'Não Definida']
# --------------------------------------------------
# Tratando a coluna 'campus'...
# Valores únicos em 'campus_tratado':
# ['Apodi', 'Caicó', 'Canguaretama', 'Ceará-Mirim', 'Currais Novos', 'Ipanguaçu', 'João Câmara', 'Jucurutu', 'Lajes', 'Macau', 'Mossoró', 'Natal - Central', 'Natal - Cidade Alta', 'Natal - Zona Leste', 'Natal - Zona Norte', 'Nova Cruz', 'Parelhas', 'Parnamirim', 'Pau dos Ferros', 'Reitoria', 'Santa Cruz', 'São Gonçalo do Amarante', 'São Paulo do Potengi']
# --------------------------------------------------
# Tratando a coluna 'setor_suap' com a lógica aperfeiçoada...
# Valores únicos antes do tratamento: 578
# Valores únicos após o tratamento: 225
# Exemplo de transformação:
#   setor_suap setor_tratado
# 0    DIAC/ZL          DIAC
# 1    DIAC/MO          DIAC
# 2    DIAD/ZN          DIAD
# 3    DIAC/MO          DIAC
# 4    DIAC/JC          DIAC
# --------------------------------------------------
# Tratando a coluna 'funcao'...
# Exemplo de transformação da coluna 'funcao':
#                                         funcao funcao_tratado
# 0   FAG-IFRN - UAB/IFRN / FAG-IFRN - CESPEP/ZL       FAG-IFRN
# 2                             CD0004 - DIAD/ZN         CD0004
# 6                            FG0002 - COLAB/JC         FG0002
# 12                       SUB-CHEFIA - DIAD/SPP     SUB-CHEFIA
# 18                      SUB-CHEFIA - DIAD/CNAT     SUB-CHEFIA
# --------------------------------------------------
# Tratando a coluna 'jornada_trabalho'...
# Exemplo de transformação da coluna 'jornada_trabalho':
#       jornada_trabalho      jornada_tratada
# 0  DEDICACAO EXCLUSIVA  Dedicação Exclusiva
# 1    40 HORAS SEMANAIS         40h Semanais
# 2    40 HORAS SEMANAIS         40h Semanais
# 3  DEDICACAO EXCLUSIVA  Dedicação Exclusiva
# 4  DEDICACAO EXCLUSIVA  Dedicação Exclusiva
# --------------------------------------------------
# Tratando a coluna 'disciplina_ingresso'...
# Exemplo de transformação da coluna 'disciplina_ingresso':
#         categoria_tratada     disciplina_ingresso        disciplina_tratada
# 0                 Docente                Didática                  Didática
# 1                 Docente                     NaN  Disciplina Não Informada
# 2  Técnico Administrativo                       -             Não se Aplica
# 3                 Docente    Instalações Prediais      Instalações Prediais
# 4                 Docente           Arte - Teatro             Arte - Teatro
# 5                 Docente  Sistemas de Informação    Sistemas de Informação
# 6  Técnico Administrativo                       -             Não se Aplica
# 7  Técnico Administrativo                       -             Não se Aplica
# 8  Técnico Administrativo                       -             Não se Aplica
# 9  Técnico Administrativo                       -             Não se Aplica
# --------------------------------------------------
# Exemplo de transformação da coluna 'cargo':
#                                      cargo                cargo_tratado
# 0    PROFESSOR ENS BASICO TECN TECNOLOGICO            Professor do Ebtt
# 1  PROF ENS BAS TEC TECNOLOGICO-SUBSTITUTO            Professor do Ebtt
# 2                            ADMINISTRADOR                Administrador
# 3    PROFESSOR ENS BASICO TECN TECNOLOGICO            Professor do Ebtt
# 4    PROFESSOR ENS BASICO TECN TECNOLOGICO            Professor do Ebtt
# 5    PROFESSOR ENS BASICO TECN TECNOLOGICO            Professor do Ebtt
# 6              TECNICO DE LABORATORIO AREA  Técnico de Laboratório/Área
# 7                                  AUDITOR                      Auditor
# 8              TECNICO DE LABORATORIO AREA  Técnico de Laboratório/Área
# 9                     AUX EM ADMINISTRACAO    Auxiliar em Administração
# --------------------------------------------------

# %%
unique_cargo_values = df['cargo_tratado'].unique()
sorted_unique_cargo_values = sorted([str(value) for value in unique_cargo_values])

print(f"\nTotal de valores exclusivos para 'cargo_tratado': {len(sorted_unique_cargo_values)}")
print("Exibindo valores exclusivos para coluna 'cargo_tratado' em ordem alfabética:")
for value in sorted_unique_cargo_values:
    print(value)
print("-" * 30)
# Out:
# Total de valores exclusivos para 'cargo_tratado': 82
# Exibindo valores exclusivos para coluna 'cargo_tratado' em ordem alfabética:
# Administrador
# Analista de Tecnologia da Informação
# Arquiteto e Urbanista
# Arquivista
# Assistente Social
# Assistente de Aluno
# Assistente de Laboratório
# Assistente em Administração
# Auditor
# Auxiliar de Artes Gráficas
# Auxiliar de Biblioteca
# Auxiliar de Eletricista
# Auxiliar de Enfermagem
# Auxiliar de Laboratório
# Auxiliar de Mecânica
# Auxiliar em Administração
# Auxiliar em Assuntos Educacionais
# Bibliotecário
# Carpinteiro
# Contador
# Desenhista Projetista
# Desenhista Técnico Especialidade
# Diagramador
# Economista
# Eletricista
# Enfermeiro do Trabalho
# Enfermeiro/Área
# Engenheiro Agrônomo
# Engenheiro de Segurança do Trabalho
# Engenheiro/Área
# Estagiário
# Estatístico
# Fisioterapeuta
# Físico
# Impressor
# Jornalista
# Marceneiro
# Mecânico
# Motorista
# Médico Veterinário
# Médico/Área
# Nutricionista/Habilitação
# Não Informado
# Odontólogo
# Operador de Maquina Copiadora
# Operador de Máquina de Lavanderia
# Operador de Tele-Impressora
# Pedagogo/Área
# Pintor/Área
# Porteiro
# Procurador Federal
# Produtor Cultural
# Professor do Ebtt
# Programador Visual
# Psicólogo/Área
# Publicitário
# Redator
# Revisor de Textos
# Secretario Executivo
# Servente de Limpeza
# Servente de Obras
# Tecnologo/Formação
# Telefonista
# Tradutor e Intérprete de Linguagem de Sinais
# Técnico de Laboratório/Área
# Técnico de Tecnologia da Informação
# Técnico em Agropecuária
# Técnico em Alimentos e Laticínios
# Técnico em Assuntos Educacionais
# Técnico em Audiovisual
# Técnico em Contabilidade
# Técnico em Edificações
# Técnico em Eletrotécnica
# Técnico em Enfermagem
# Técnico em Higiene Dental
# Técnico em Mecânica
# Técnico em Metrologia e Qualidade
# Técnico em Mineração
# Técnico em Química
# Técnico em Secretariado
# Técnico em Segurança do Trabalho
# Vigilante
# ------------------------------

# %%
columns_to_display = ['setor_tratado']

for column in columns_to_display:
    unique_values_count = df[column].value_counts()
    print(f"Contagem de valores exclusivos para coluna '{column}':")
    display(unique_values_count)
    print("-" * 30)
# Out:
# Contagem de valores exclusivos para coluna 'setor_tratado':
# setor_tratado
# DIAC         1343
# COAES         134
# COLAB          79
# COAPAC         70
# SEAC           59
#              ...
# COORD_MEC       1
# DEAD            1
# COMEC           1
# COEECI          1
# CCEDIIT         1
# Name: count, Length: 225, dtype: int64
# ------------------------------

# %%
columns_to_display = ['funcao_tratado']

for column in columns_to_display:
    unique_values_count = df[column].value_counts()
    print(f"Contagem de valores exclusivos para coluna '{column}':")
    display(unique_values_count)
    print("-" * 30)
# Out:
# Contagem de valores exclusivos para coluna 'funcao_tratado':
# funcao_tratado
# Sem Função        2237
# FG0002             148
# FUC0001            123
# FG0001             110
# SUB-CHEFIA         105
# FAG-IFRN            95
# CD0004              59
# CD0003              23
# CD0002              22
# FACC-IFRN           11
# FG                   7
# SUB-CHEFIA0002       5
# FG2                  5
# FAA                  3
# FG1                  3
# FUC1                 3
# CD4                  2
# SUB-CHEFIAFG-1       2
# FG4                  1
# CD3                  1
# SUB-CHEFIACD-4       1
# CD0001               1
# SUB-CHEFIA0001       1
# FAA4                 1
# FUC                  1
# CD2                  1
# SUB-CHEFIA2          1
# Name: count, dtype: int64
# ------------------------------

# %%
# --- 3. Limpeza e Seleção de Colunas ---
print("Selecionando e renomeando colunas para o DataFrame final...")
colunas_uteis = [
    'nome', 'matricula', 'categoria_tratada', 'campus_tratado',
    'setor_tratado', 'funcao_tratado', 'cargo_tratado',
    'jornada_tratada', 'disciplina_tratada'
]
df_servidores_bi = df[colunas_uteis].copy()

df_servidores_bi.rename(columns={
    'nome': 'Nome_do_Servidor',
    'matricula': 'Matricula',
    'categoria_tratada': 'Vinculo_de_Carreira',
    'campus_tratado': 'Campus_do_IFRN',
    'setor_tratado': 'Setor',
    'funcao_tratado': 'Funcao',
    'cargo_tratado': 'Cargo',
    'jornada_tratada': 'Jornada_de_Trabalho',
    'disciplina_tratada': 'Disciplina_de_Ingresso'
}, inplace=True)

df_servidores_bi['Ano'] = data
df['Ano'] = pd.to_datetime(df['Ano'], errors='coerce')

display(df_servidores_bi.head())
print("-" * 50)
# Out:
# Selecionando e renomeando colunas para o DataFrame final...
# /tmp/ipython-input-1070266850.py:23: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Ano'] = pd.to_datetime(df['Ano'], errors='coerce')
#                         Nome_do_Servidor Matricula     Vinculo_de_Carreira  \
# 0       Abigail Noadia Barbalho da Silva   1895370                 Docente
# 1  Abimael Esdras Carvalho de Moura Lira   3268131                 Docente
# 2                Abinoam Soares da Silva   1845427  Técnico Administrativo
# 3          Abraao Jhonny da Costa Brazao   1266198                 Docente
# 4          Abraao Lincoln Rosendo Frazao   2460058                 Docente
#
#        Campus_do_IFRN Setor      Funcao              Cargo  \
# 0  Natal - Zona Leste  DIAC    FAG-IFRN  Professor do Ebtt
# 1             Mossoró  DIAC  Sem Função  Professor do Ebtt
# 2  Natal - Zona Norte  DIAD      CD0004      Administrador
# 3             Mossoró  DIAC  Sem Função  Professor do Ebtt
# 4         João Câmara  DIAC  Sem Função  Professor do Ebtt
#
#    Jornada_de_Trabalho    Disciplina_de_Ingresso         Ano
# 0  Dedicação Exclusiva                  Didática  13/03/2025
# 1         40h Semanais  Disciplina Não Informada  13/03/2025
# 2         40h Semanais             Não se Aplica  13/03/2025
# 3  Dedicação Exclusiva      Instalações Prediais  13/03/2025
# 4  Dedicação Exclusiva             Arte - Teatro  13/03/2025
# --------------------------------------------------

# %%
print("DataFrame final pronto para BI:")
print(df_servidores_bi.info())
print("-" * 50)
# Out:
# DataFrame final pronto para BI:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2972 entries, 0 to 2971
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Nome_do_Servidor        2972 non-null   object
#  1   Matricula               2972 non-null   object
#  2   Vinculo_de_Carreira     2972 non-null   object
#  3   Campus_do_IFRN          2972 non-null   object
#  4   Setor                   2972 non-null   object
#  5   Funcao                  2972 non-null   object
#  6   Cargo                   2972 non-null   object
#  7   Jornada_de_Trabalho     2972 non-null   object
#  8   Disciplina_de_Ingresso  2972 non-null   object
#  9   Ano                     2972 non-null   object
# dtypes: object(10)
# memory usage: 232.3+ KB
# None
# --------------------------------------------------

# %%
# @title --- 4. Exportação para o BigQuery ---

# --- Configurações de Destino do BigQuery ---
project_id = "pnp-data-extraction" # Substitua pelo ID do seu projeto
dataset_id = "pnp_dados_IFRN"      # Nome do conjunto de dados que você já criou
table_id = "df_servidores_ifrn"       # Nome da tabela que será criada ou substituída
destination_table = f"{dataset_id}.{table_id}"

# --- Definição do Esquema da Tabela (Opcional, mas recomendado) ---
# Com base na saída do df.info(), todas as colunas são objetos (strings).
table_schema = [
    {'name': 'Nome_do_Servidor', 'type': 'STRING'},
    {'name': 'Matricula', 'type': 'STRING'},
    {'name': 'Vinculo_de_Carreira', 'type': 'STRING'},
    {'name': 'Campus_do_IFRN', 'type': 'STRING'},
    {'name': 'Setor', 'type': 'STRING'},
    {'name': 'Funcao', 'type': 'STRING'},
    {'name': 'Cargo', 'type': 'STRING'},
    {'name': 'Jornada_de_Trabalho', 'type': 'STRING'},
    {'name': 'Disciplina_de_Ingresso', 'type': 'STRING'},
    {'name': 'Ano', 'type': 'STRING'}
]

# --- Execução da Exportação ---
# Verifica se o DataFrame final não está vazio
if not df_servidores_bi.empty:
    print(f"Iniciando a exportação de {len(df_servidores_bi):,} linhas para o BigQuery...")
    print(f"Destino: {project_id}.{destination_table}")

    try:
        # Envia o DataFrame para o BigQuery, especificando o esquema.
        pandas_gbq.to_gbq(
            df_servidores_bi,
            destination_table=destination_table,
            project_id=project_id,
            if_exists='replace',
            table_schema=table_schema, # Adicionamos o esquema aqui
            progress_bar=True
        )
        print(f"\n✔ DataFrame exportado com sucesso para o BigQuery!")
        print(f"Link para a tabela: https://console.cloud.google.com/bigquery?project={project_id}&ws=!1m5!1m4!4m3!1s{project_id}!2s{dataset_id}!3s{table_id}")
    except Exception as e:
        print(f"❌ ERRO durante a exportação para o BigQuery: {e}")
else:
    print("⚠️ AVISO: O DataFrame final está vazio. Nenhuma exportação foi realizada.")
# Out:
# Iniciando a exportação de 2,972 linhas para o BigQuery...
# Destino: pnp-data-extraction.pnp_dados_IFRN.df_servidores_ifrn
# 100%|██████████| 1/1 [00:00<00:00, 9238.56it/s]
# ✔ DataFrame exportado com sucesso para o BigQuery!
# Link para a tabela: https://console.cloud.google.com/bigquery?project=pnp-data-extraction&ws=!1m5!1m4!4m3!1spnp-data-extraction!2spnp_dados_IFRN!3sdf_servidores_ifrn
